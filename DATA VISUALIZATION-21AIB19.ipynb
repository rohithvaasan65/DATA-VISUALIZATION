# %% [markdown]
# #Numpy is to handle the Numerical Values

# %%
import numpy as np

# %% [markdown]
# #Pandas is used to Read(or)Write the CSV .Mostly the DataSet are in the form of .csv

# %%
import pandas as pd

# %% [markdown]
# #The Matplotlib is used Visualize the Data in the Graph form

# %%
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv("/content/International_Report_Departures.csv")

# %%
df2=pd.read_csv("/content/International_Report_Passengers.csv")

# %% [markdown]
# The Dataset is have more then 4,000 so for practice the take 100 datas

# %%
data_1=df1.head(100)

# %%
data1=df1.sample(100)

# %%
data2=df2.sample(100)

# %%
data_2=df2.head(100)

# %%
data_1.describe()
# Out:
#              Year       Month    usg_apt_id     usg_wac     fg_apt_id  \
# count   100.00000  100.000000    100.000000  100.000000    100.000000
# mean   2005.50000    5.840000  13072.110000   42.240000  13579.730000
# std       2.65718    3.498109   1417.514868   25.174189   1878.552967
# min    2001.00000    1.000000  10299.000000    1.000000  10371.000000
# 25%    2003.75000    3.000000  12016.000000   22.000000  11914.500000
# 50%    2005.00000    5.500000  13221.000000   33.500000  13556.000000
# 75%    2008.00000    9.000000  13954.250000   64.000000  15174.000000
# max    2010.00000   12.000000  16091.000000   93.000000  16334.000000
#
#            fg_wac     airlineid  carriergroup  Scheduled     Charter  \
# count  100.000000    100.000000     100.00000      100.0  100.000000
# mean   460.240000  20241.400000       0.79000        0.0    8.070000
# std    298.348421    339.791766       0.40936        0.0   15.993215
# min    110.000000  19531.000000       0.00000        0.0    1.000000
# 25%    148.000000  20085.500000       1.00000        0.0    1.000000
# 50%    429.000000  20201.000000       1.00000        0.0    2.000000
# 75%    746.500000  20402.000000       1.00000        0.0    8.000000
# max    941.000000  21437.000000       1.00000        0.0  124.000000
#
#             Total
# count  100.000000
# mean     8.070000
# std     15.993215
# min      1.000000
# 25%      1.000000
# 50%      2.000000
# 75%      8.000000
# max    124.000000

# %%
data_2.describe()
# Out:
#               Year      Month    usg_apt_id     usg_wac     fg_apt_id  \
# count   100.000000  100.00000    100.000000  100.000000    100.000000
# mean   2005.060000    6.06000  12767.510000   44.140000  13740.920000
# std       2.834919    3.53859   1529.187356   27.547579   2039.701779
# min    2001.000000    1.00000  10140.000000    1.000000  10148.000000
# 25%    2003.000000    3.00000  11423.000000   22.000000  11784.750000
# 50%    2005.000000    6.00000  13034.000000   40.000000  13605.000000
# 75%    2007.000000    9.00000  13954.250000   64.000000  16097.750000
# max    2014.000000   12.00000  15376.000000   93.000000  16321.000000
#
#            fg_wac     airlineid  carriergroup  Scheduled      Charter  \
# count  100.000000    100.000000    100.000000      100.0   100.000000
# mean   443.720000  20238.180000      0.720000        0.0   704.350000
# std    325.944783    305.079105      0.451261        0.0  1119.601366
# min    106.000000  19386.000000      0.000000        0.0     2.000000
# 25%    148.000000  20147.000000      0.000000        0.0    49.000000
# 50%    251.000000  20308.500000      1.000000        0.0   227.000000
# 75%    843.750000  20377.000000      1.000000        0.0   695.500000
# max    961.000000  21186.000000      1.000000        0.0  6469.000000
#
#              Total
# count   100.000000
# mean    704.350000
# std    1119.601366
# min       2.000000
# 25%      49.000000
# 50%     227.000000
# 75%     695.500000
# max    6469.000000

# %%
data_1.head()
# Out:
#      data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  05/01/2006  2006      5       12016     GUM        5      13162    MAJ
# 1  05/01/2003  2003      5       10299     ANC        1      13856    OKO
# 2  03/01/2007  2007      3       10721     BOS       13      12651    KEF
# 3  12/01/2004  2004     12       11259     DAL       74      16271    YYZ
# 4  05/01/2009  2009      5       13303     MIA       33      11075    CMW
#
#    fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0     844      20177     PFQ             1  Departures          0       10
# 1     736      20007      5Y             1  Departures          0       15
# 2     439      20402      GL             1  Departures          0        1
# 3     936      20201     AMQ             1  Departures          0        1
# 4     219      21323      5L             0  Departures          0       20
#
#    Total
# 0     10
# 1     15
# 2      1
# 3      1
# 4     20

# %%
A=data_1.groupby("Month")
A.get_group(5)
# Out:
#       data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0   05/01/2006  2006      5       12016     GUM        5      13162    MAJ
# 1   05/01/2003  2003      5       10299     ANC        1      13856    OKO
# 4   05/01/2009  2009      5       13303     MIA       33      11075    CMW
# 14  05/01/2009  2009      5       13930     ORD       41      11032    CUN
# 20  05/01/2006  2006      5       13796     OAK       91      16042    YEG
# 22  05/01/2010  2010      5       14050     PDK       34      10591    BHD
# 85  05/01/2007  2007      5       13697     NKT       36      14889    SMA
#
#     fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0      844      20177     PFQ             1  Departures          0       10
# 1      736      20007      5Y             1  Departures          0       15
# 4      219      21323      5L             0  Departures          0       20
# 14     148      19534      AM             0  Departures          0       10
# 20     916      19531      AC             0  Departures          0        1
# 22     493      21131     VSA             0  Departures          0        1
# 85     469      20213     POQ             0  Departures          0        1
#
#     Total
# 0      10
# 1      15
# 4      20
# 14     10
# 20      1
# 22      1
# 85      1

# %%
print(pd.merge(df1,df2,left_index=True,right_index=True))
# Out:
#         data_dte_x  Year_x  Month_x  usg_apt_id_x usg_apt_x  usg_wac_x  \
# 0       05/01/2006    2006        5         12016       GUM          5
# 1       05/01/2003    2003        5         10299       ANC          1
# 2       03/01/2007    2007        3         10721       BOS         13
# 3       12/01/2004    2004       12         11259       DAL         74
# 4       05/01/2009    2009        5         13303       MIA         33
# ...            ...     ...      ...           ...       ...        ...
# 680980  11/01/1993    1993       11         12892       LAX         91
# 680981  09/01/1995    1995        9         12892       LAX         91
# 680982  12/01/2016    2016       12         14100       PHL         23
# 680983  06/01/1999    1999        6         12892       LAX         91
# 680984  12/01/2016    2016       12         14100       PHL         23
#
#         fg_apt_id_x fg_apt_x  fg_wac_x  airlineid_x  ... fg_apt_id_y  \
# 0             13162      MAJ       844        20177  ...       11032
# 1             13856      OKO       736        20007  ...       16085
# 2             12651      KEF       439        20402  ...       10411
# 3             16271      YYZ       936        20201  ...       16304
# 4             11075      CMW       219        21323  ...       11138
# ...             ...      ...       ...          ...  ...         ...
# 680980        15306      TPE       781        20005  ...       12972
# 680981        14832      SJD       148        19875  ...       12972
# 680982        10920      CDG       427        19805  ...       12972
# 680983        16306      ZLO       148        19875  ...       12972
# 680984        11651      FCO       450        19805  ...       12972
#
#         fg_apt_y fg_wac_y  airlineid_y  carrier_y  carriergroup_y      type_y  \
# 0            CUN      148        19534         AM               0  Passengers
# 1            YHZ      951        20364         C6               0  Passengers
# 2            AUA      277        20344         RD               1  Passengers
# 3            ZIH      148        20204         MG               1  Passengers
# 4            CRK      766        20312         TZ               1  Passengers
# ...          ...      ...          ...        ...             ...         ...
# 680980       LHR      493        19540         BA               0  Passengers
# 680981       LHR      493        19540         BA               0  Passengers
# 680982       LHR      493        19540         BA               0  Passengers
# 680983       LHR      493        19540         BA               0  Passengers
# 680984       LHR      493        19540         BA               0  Passengers
#
#         Scheduled_y  Charter_y  Total_y
# 0                 0        315      315
# 1                 0        683      683
# 2                 0       1010     1010
# 3                 0        508      508
# 4                 0         76       76
# ...             ...        ...      ...
# 680980       130217          0   130217
# 680981       132052          0   132052
# 680982       132822          0   132822
# 680983       134263          0   134263
# 680984       149898        297   150195
#
# [680985 rows x 32 columns]

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      100 non-null    object
#  1   Year          100 non-null    int64
#  2   Month         100 non-null    int64
#  3   usg_apt_id    100 non-null    int64
#  4   usg_apt       100 non-null    object
#  5   usg_wac       100 non-null    int64
#  6   fg_apt_id     100 non-null    int64
#  7   fg_apt        100 non-null    object
#  8   fg_wac        100 non-null    int64
#  9   airlineid     100 non-null    int64
#  10  carrier       98 non-null     object
#  11  carriergroup  100 non-null    int64
#  12  type          100 non-null    object
#  13  Scheduled     100 non-null    int64
#  14  Charter       100 non-null    int64
#  15  Total         100 non-null    int64
# dtypes: int64(11), object(5)
# memory usage: 12.6+ KB

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 319802 to 395742
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      100 non-null    object
#  1   Year          100 non-null    int64
#  2   Month         100 non-null    int64
#  3   usg_apt_id    100 non-null    int64
#  4   usg_apt       100 non-null    object
#  5   usg_wac       100 non-null    int64
#  6   fg_apt_id     100 non-null    int64
#  7   fg_apt        100 non-null    object
#  8   fg_wac        100 non-null    int64
#  9   airlineid     100 non-null    int64
#  10  carrier       100 non-null    object
#  11  carriergroup  100 non-null    int64
#  12  type          100 non-null    object
#  13  Scheduled     100 non-null    int64
#  14  Charter       100 non-null    int64
#  15  Total         100 non-null    int64
# dtypes: int64(11), object(5)
# memory usage: 13.3+ KB

# %%
X=data_1.Year
Y=data_1.Month
plt.xlabel('Year')
plt.ylabel('Charter')
plt.pie(X,Y)
plt.show()

# %% [markdown]
# Below code of line is for Scatter plot

# %%
plt.scatter(X,Y)
plt.show()

# %%
data_1.plot()

# %%
data1.plot()

# %% [markdown]
# Below code is to represent the bar graph

# %%
data_1.plot(kind='bar')

# %%
data1.plot(kind='bar')

# %% [markdown]
# TO get Information from the dataset

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      100 non-null    object
#  1   Year          100 non-null    int64
#  2   Month         100 non-null    int64
#  3   usg_apt_id    100 non-null    int64
#  4   usg_apt       100 non-null    object
#  5   usg_wac       100 non-null    int64
#  6   fg_apt_id     100 non-null    int64
#  7   fg_apt        100 non-null    object
#  8   fg_wac        100 non-null    int64
#  9   airlineid     100 non-null    int64
#  10  carrier       98 non-null     object
#  11  carriergroup  100 non-null    int64
#  12  type          100 non-null    object
#  13  Scheduled     100 non-null    int64
#  14  Charter       100 non-null    int64
#  15  Total         100 non-null    int64
# dtypes: int64(11), object(5)
# memory usage: 12.6+ KB

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 281180 to 400020
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      100 non-null    object
#  1   Year          100 non-null    int64
#  2   Month         100 non-null    int64
#  3   usg_apt_id    100 non-null    int64
#  4   usg_apt       100 non-null    object
#  5   usg_wac       100 non-null    int64
#  6   fg_apt_id     100 non-null    int64
#  7   fg_apt        100 non-null    object
#  8   fg_wac        100 non-null    int64
#  9   airlineid     100 non-null    int64
#  10  carrier       99 non-null     object
#  11  carriergroup  100 non-null    int64
#  12  type          100 non-null    object
#  13  Scheduled     100 non-null    int64
#  14  Charter       100 non-null    int64
#  15  Total         100 non-null    int64
# dtypes: int64(11), object(5)
# memory usage: 13.3+ KB

# %%
x=data_2.airlineid
y=data_2.Month 
plt.xlabel("airlineid")     
plt.ylabel("Month")  
plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y)

# %%
plt.pie(x,y)
plt.show()

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      100 non-null    object
#  1   Year          100 non-null    int64
#  2   Month         100 non-null    int64
#  3   usg_apt_id    100 non-null    int64
#  4   usg_apt       100 non-null    object
#  5   usg_wac       100 non-null    int64
#  6   fg_apt_id     100 non-null    int64
#  7   fg_apt        100 non-null    object
#  8   fg_wac        100 non-null    int64
#  9   airlineid     100 non-null    int64
#  10  carrier       98 non-null     object
#  11  carriergroup  100 non-null    int64
#  12  type          100 non-null    object
#  13  Scheduled     100 non-null    int64
#  14  Charter       100 non-null    int64
#  15  Total         100 non-null    int64
# dtypes: int64(11), object(5)
# memory usage: 12.6+ KB

# %%
data_2.plot(kind='bar')
